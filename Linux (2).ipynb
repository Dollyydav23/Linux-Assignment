# %% [markdown]
# #LINUX ASSIGNMENT

# %% [markdown]
# 1.What is Linux?
#  - Linux is a free and open-source operating system based on the Linux kernel, which was created by Linus Torvalds in 1991. It is similar to UNIX and serves as a bridge between computer hardware and software, managing resources like memory, CPU, and storage. Anyone can inspect and modify the source code, which enables global collaboration and innovation. Its efficient performance and strong security model make it suitable for a wide variety of devices and industries.

# %% [markdown]
# 2. What is the difference between Hard Link & Soft Link?
#   - In Linux, links are used to create references (pointers) to files. While they serve similar purposes, they differ significantly in functionality, behavior, and use cases.
#
#     The difference between Hard link and soft link are as follows:
#
#     **Hard link**:A Hard link acts as a copy (mirrored) of the selected file. It accesses the data available in the original file. If the earlier selected file is deleted, the hard link to the file will still contain the data of that file.
#
#     **1. Inode:**Both the original file and the hard link share the same inode number.
#
#     **2. File system:** Hard link cannot used acrross file systems.
#
#     **3. Directories:** Hard links are not allowed for directories. (Only a superuser* can do it)
#
#     **Soft Link:** A soft link acts as a pointer or a reference to the file name. It does not access the data available in the original file. If the earlier file is deleted, the soft link will be pointing to a file that does not exist anymore.
#
#     **1. Inode:** Files that are soft linked take a different inode number.
#
#     **2. File system:** Soft link can be used acrross file systems.
#
#     **3. Directories:** Soft links can be used for linking directories.

# %% [markdown]
# 3.  What is a Kernel in Linux?
#   - The Linux kernel is the core component of the Linux operating system, acting as the critical interface between the computer's hardware and its software processes.The Linux kernel is the core component of the Linux operating system, acting as the critical interface between the computer's hardware and its software processes
#
#      Its is responsible for the following actions:
#      1. Memory allocation
#      2. Process management
#      3. File managemnet
#      4. Resource Management
#      5. Device Management

# %% [markdown]
# 4. How do you create a user account?
#   - In Linux, adding a user is a fundamental administrative task that can be accomplished using the useradd command. This command allows you to create new user accounts with various options to customize the user's settings.
#
#     **User Creation:** To create a new user, you can use the useradd command followed by the username
#
#     -->Syntax:  sudo useradd dolly
#
#     **Password:** After creating the user, you need to set a password for the user to enable login. Use the passwd command:
#
#     You will be prompted to enter and confirm the password
#
#     -->Syntax: sudo passwd dolly**23
#
#      ** Example:**
#
#       bash
#
#      sudo adduser dolly
#
#      sudo useradd -m -s /bin/bash dolly
#
#      sudo passwd dolly

# %% [markdown]
# 5.  What is the ‘grep’ command used for in Linux?
#    - grep is a command-line utility in Linux that is used to search for specific patterns of text within files. The name grep stands for “Global Regular Expression Print.” It searches through the contents of files line by line and displays the lines that match the given pattern.
#
#       **It is commonly used for:**
#
#      Finding specific words or phrases in files.
#
#      Filtering command output to display only relevant information.
#
#      Searching logs and configuration files for errors or specific entrie
#
#      **For Example: **
#
#      grep "pattern" filename
#
#
# ![WindowsTerminal_d83uzZTem6.png](data:image/png;base64,...)

# %% [markdown]
# 6.  Step1: Create user p1
#
#  Step2: He should be part of 3 groups g1,g2,g3.
#
#  Step3: whenever he creates a file automatically in the group section of file grp g1 should come.
#
#    - **Step1:** Creating user p1
#
#       To create a new user named p1, use the following command:
#
#       sudo useradd p1
#
#       sudo passwd p1  # (Set a password for user p1)
#
#       **Step 2:** Add User p1 to Groups g1, g2, and g3
#
#       now i have  create the 3 groups: **g1, g2, g3**
#
#       sudo groupadd g1
#
#       sudo groupadd g2
#
#       sudo groupadd g3
#
#       Next, adding the user p1 to all three groups:
#
#       Let’s make g1 the primary group for p1 and add the user’s home too:
#
#       sudo useradd -g g1 -G g2,g3 -m -s /bin/bash p1
#
#       here, i have set g1 as primary group and g2 , g3 added as supplementary groups to p1.
#
#      **Step 3:** whenever he creates a file automatically in the group section of file grp g1 should come.
#
#      So, When p1 creates a file, that file’s group owner should automatically be g1.
#
#      By default, when a user creates a file:
#
#      The primary group of the user is used as the group owner of the file.
#
#      So if p1 has g1 as their primary group, then all new files created by p1 will automatically have g1 as the group.
#
# ![que6.png](data:image/png;base64,...)
#
#      So,
#
#      If p1’s primary group is g1 → files automatically get g1 as the group.

# %% [markdown]
#  7.   Step1: Create directory /tmp/bg as root user and create files inside it.
#
#  Step2: “abhi” should be the owner of the directory. He should be able to create files and delete files inside the directory and also he should be able to add content to all files inside the directory.
#
#    - **Step 1:** Creating a directory /tmp/bg as root
#
#        --> mkdir -p /tmp/bg
#
#         Creating files inside /tmp/bg
#
#         -->touch file{1..3}.txt
#
#         **Step 2:** Now creating the owner of the directory "abhi" and He should be able to create, delete, and edit files inside it.
#
#         Creating the user 'abhi' with a home directory
#
#          --> sudo useradd abhi
#
#          Changing the owner of /tmp/bg to 'abhi'
#
#          --> sudo chown abhi /tmp/bg
#
#          Giving the owner full permissions to the directory
#
#          --> sudo chmod u+rwx /tmp/bg
#
#          Giving the owner read and write permissions to all files inside the directory
#
#          --> sudo chmod u+rw /tmp/bg/*
#
# ![ques_7.png](data:image/png;base64,...)
#
#
#
#          The user abhi is the owner of /tmp/bg. Abhi can create new files, delete files, and add or modify content inside any file within the directory.

# %% [markdown]
# 8. You suspect that a particular process is consuming excessive CPU resources on your Linux server. How would you identify and terminate this process.
#   -  identifing and terminating a process that is consuming excessive CPU resources on a Linux server:
#
#     **Follow the Steps:**
#
#      **step 1:** using top command to monitor running processes and check their CPU usage
#
#      --> top
#
#      i have used ps command with sorting which sort the all running processes sorted by CPU usage in descending order, so the processes consuming the highest CPU are listed first.
#
#      --> ps aux --sort=-%cpu
#
#      The highest %CPU value is 0.1% for the first process:
#
#     **output:**
#
#      root           1  0.1  0.1  21496 12840 ?        Ss   17:43   0:00 /sbin/init
#
#      **Step 2:** Terminate the process
#
#     using the kill command to stop the process.
#
#     --> sudo kill -9 1
#
#     Never run sudo kill -9 1 because PID 1 is the system’s main init process — killing it can crash the entire system. Always identify the correct PID of the high-CPU process and only terminate that specific process.
